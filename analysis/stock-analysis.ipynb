# %%
import info
import measures
import plot

# %%
info.get_sectors()
# Out:
#                   SETOR                        SUBSETOR  \
# 0   Consumo não Cíclico                    Agropecuária
# 5            Financeiro      Intermediários Financeiros
# 11                Saúde         Comércio e Distribuição
# 16                Saúde  Medicamentos e Outros Produtos
# 18    Utilidade Pública                Energia Elétrica
# 26    Utilidade Pública               Água e Saneamento
#
#                           SEGMENTO
# 0                      Agricultura
# 5                           Bancos
# 11  Medicamentos e Outros Produtos
# 16  Medicamentos e Outros Produtos
# 18                Energia Elétrica
# 26               Água e Saneamento

# %%
info.get_companies_by_segmento("Energia Elétrica")
# Out:
#     CD_CVM                                   DENOM_COMERC MAIN_TICKER  \
# 18    2437                                     ELETROBRAS       ELET3
# 19    2453                                          CEMIG       CMIG4
# 20   15539                                NEOENERGIA S.A.       NEOE3
# 21   17329                              TRACTEBEL ENERGIA       EGIE3
# 22   18376                                          CTEEP       TRPL4
# 23   18660                              CPFL ENERGIA S.A.       CPFE3
# 24   20010                         EQUATORIAL ENERGIA S/A       EQTL3
# 25   20257  TRANSMISSORA ALIANÇA DE ENERGIA ELÉTRICA S.A.       TAEE4
#
#     FOUNDATION
# 18        1962
# 19        1952
# 20        1997
# 21        1998
# 22        1999
# 23        1998
# 24        1999
# 25        2006

# %%
measures.get_latest_values_by_segmento("Energia Elétrica")
# Out:
#      TICKER      PRICE       BAZIN         PL       PVP  DIVIDEND_YIELD  \
# 0     ELET3  38.080002   34.693593  19.772755  0.769100        0.010604
# 1     EQTL3  31.900000   13.777565  12.471831  1.486651        0.014106
# 2     CPFE3  32.720001   61.563567   6.861174  1.870994        0.084168
# 3     EGIE3  40.799999  141.793116   7.618701  2.759209        0.062249
# 4     CMIG4  11.030000   37.289399   5.292022  1.183218        0.165968
# 5     NEOE3  19.230000   22.213214   5.131088  0.733404        0.043150
# 6     TRPL4  24.510000   86.839221   5.914494  0.845822        0.089926
# 7     TAEE4  11.550000   42.639329   7.761800  1.763664        0.099776
# 0  SEGMENTO   0.000000    0.000000   8.852983  1.426508        0.071243
#
#    DIVIDEND_PAYOUT       ROE  CGAR_5_YEARS_PROFIT  CGAR_5_YEARS_REVENUE  \
# 0         0.209671  0.038897            -0.238640              0.158147
# 1         0.175932  0.119201             0.152833              0.241399
# ...

# %%
ticker = "CMIG4"
show_segment = True

plot.plot_equity_evolution(ticker)
plot.plot_historical_kpi(ticker, kpi="NET_DEBT_BY_EQUITY", show_segment=show_segment)
plot.plot_historical_kpi(ticker, kpi="NET_DEBT_BY_EBIT", show_segment=show_segment)
plot.plot_historical_kpi(ticker, kpi="PROFIT", show_segment=show_segment)
plot.plot_historical_kpi(ticker, kpi="ROE", show_segment=show_segment)
plot.plot_historical_kpi(ticker, kpi="CGAR_5_YEARS_PROFIT", show_segment=show_segment)
plot.plot_historical_kpi(ticker, kpi="DIVIDEND_YIELD", show_segment=show_segment)
plot.plot_historical_kpi(ticker, kpi="DIVIDEND_PAYOUT", show_segment=show_segment)
plot.plot_historical_kpi(ticker, kpi="NET_MARGIN", show_segment=show_segment)
