# %%
import info
import measures
import plot

### For testing purposes
# %load_ext autoreload
# %autoreload 2

# %%
info.get_sectors()
# Out:
#                   SETOR                        SUBSETOR  \
# 0   Consumo não Cíclico                    Agropecuária
# 5            Financeiro      Intermediários Financeiros
# 11                Saúde         Comércio e Distribuição
# 16                Saúde  Medicamentos e Outros Produtos
# 18    Utilidade Pública                Energia Elétrica
# 26    Utilidade Pública               Água e Saneamento
#
#                           SEGMENTO
# 0                      Agricultura
# 5                           Bancos
# 11  Medicamentos e Outros Produtos
# 16  Medicamentos e Outros Produtos
# 18                Energia Elétrica
# 26               Água e Saneamento

# %%
info.get_companies_by_segmento("Água e Saneamento")
# Out:
#     CD_CVM                                  DENOM_COMERC MAIN_TICKER  \
# 26   14443                                        SABESP       SBSP3
# 27   16861                                         CASAN       CASN4
# 28   18627                                       SANEPAR       SAPR4
# 29   19445                                     COPASA MG       CSMG3
# 30   24961  AMBIPAR PARTICIPAÇÕES E EMPREENDIMENTOS S.A.       AMBP3
# 31   25550           ORIZON VALORIZAÇÃO DE RESÍDUOS S.A.       ORVR3
#
#     FOUNDATION
# 26        1973
# 27        1970
# 28        1963
# 29        1963
# 30        1995
# 31        2009

# %%
measures.get_latest_values_by_segmento("Água e Saneamento")
# Out:
#      TICKER       PRICE      BAZIN          PL       PVP  DIVIDEND_YIELD  \
# 0     SBSP3   91.449997  50.258889   11.249766  1.965808        0.015751
# 1     AMBP3  126.800003   2.953185 -148.165910  8.345548        0.000000
# 2     CSMG3   22.290001  50.383793    5.769462  1.110530        0.162679
# 3     SAPR4    5.580000  14.093377    5.560046  0.828359        0.049840
# 4     CASN4    6.557730   1.205730   64.753798  3.566974        0.001843
# 5     ORVR3   45.750000   1.205730   27.589790  4.693191        0.000000
# 0  SEGMENTO    0.000000   0.000000   -5.540508  3.418402        0.038352
#
#    DIVIDEND_PAYOUT       ROE  CGAR_5_YEARS_PROFIT  CGAR_5_YEARS_REVENUE  \
# 0         0.177192  0.174742             0.118470              0.185720
# 1        -0.000000 -0.056326             0.118470              0.185720
# 2         0.938570  0.192484             0.192142              0.095856
# 3         0.277113  0.148984             0.109498              0.089537
# 4         0.119347  0.055085             0.056129              0.099865
# 5         0.000000  0.170106             0.056129              0.099865
# 0         0.252037  0.114179             0.119059              0.117744
#
#    NET_MARGIN  NET_DEBT_BY_EBIT  NET_DEBT_BY_EQUITY        PROFIT  \
# 0    0.142902          1.625806            0.522793  5.556291e+09
# 1   -0.027443          4.787212            2.091078 -1.429540e+08
# 2    0.190831          2.207992            0.582763  1.469087e+09
# 3    0.227551          2.059398            0.485895  1.516629e+09
# 4    0.065744          4.714448            0.864522  1.165290e+08
# 5    0.168696          3.581450            1.191099  1.375510e+08
# 0    0.128047          3.162718            0.956358  0.000000e+00
#
#    PROFIT_SEGMENTO   NET_REVENUE  NET_REVENUE_SEGMENTO          EBIT  \
# 0     4.832016e+09  3.888180e+10          3.408672e+10  1.022464e+10
# 1     1.637361e+09  5.209203e+09          1.155051e+10  1.108606e+09
# 2     6.552133e+08  7.698348e+09          4.622102e+09  2.014405e+09
# 3     6.518649e+08  6.665008e+09          4.598481e+09  2.401825e+09
# 4     5.833097e+08  1.772466e+09          4.114868e+09  3.879220e+08
# 5     2.933675e+08  8.153790e+08          2.069516e+09  2.689260e+08
# 0     0.000000e+00  0.000000e+00          0.000000e+00  0.000000e+00
#
#    EBIT_SEGMENTO
# 0   9.161496e+09
# 1   3.104434e+09
# 2   1.242283e+09
# 3   1.235935e+09
# 4   1.105954e+09
# 5   5.562244e+08
# 0   0.000000e+00

# %%
tickers=["CSMG3", "SAPR4", "SBSP3"]
show_segment = False
show_trend = True

# for ticker in tickers:
#     plot.plot_equity_evolution(ticker)
    
# plot.plot_historical_kpi(tickers=tickers, kpi="NET_DEBT_BY_EQUITY", show_segment=show_segment, show_trend=show_trend)
# plot.plot_historical_kpi(tickers=tickers, kpi="NET_DEBT_BY_EBIT", show_segment=show_segment, show_trend=show_trend)
# plot.plot_historical_kpi(tickers=tickers, kpi="PROFIT", show_segment=show_segment, show_trend=show_trend)
# plot.plot_historical_kpi(tickers=tickers, kpi="ROE", show_segment=show_segment, show_trend=show_trend)
# plot.plot_historical_kpi(tickers=tickers, kpi="CGAR_5_YEARS_PROFIT", show_segment=show_segment, show_trend=show_trend)
# plot.plot_historical_kpi(tickers=tickers, kpi="DIVIDEND_YIELD", show_segment=show_segment, show_trend=show_trend)
plot.plot_historical_kpi(tickers=tickers, kpi="DIVIDEND_PAYOUT", show_segment=show_segment, show_trend=show_trend)
# plot.plot_historical_kpi(tickers=tickers, kpi="NET_MARGIN", show_segment=show_segment, show_trend=show_trend)
# Out:
# 5383        NaN
# 5384        NaN
# 5385        NaN
# 5386        NaN
# 5387        NaN
#          ...
# 5998    0.93857
# 5999    0.93857
# 6000    0.93857
# 6001    0.93857
# 6002    0.93857
# Name: DIVIDEND_PAYOUT, Length: 620, dtype: float64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 14
#       3 show_trend = True
#       5 # for ticker in tickers:
#       6 #     plot.plot_equity_evolution(ticker)
#       7
#    (...)
#      12 # plot.plot_historical_kpi(tickers=tickers, kpi="CGAR_5_YEARS_PROFIT", show_segment=show_segment, show_trend=show_trend)
#      13 # plot.plot_historical_kpi(tickers=tickers, kpi="DIVIDEND_YIELD", show_segment=show_segment, show_trend=show_trend)
# ---> 14 plot.plot_historical_kpi(tickers=tickers, kpi="DIVIDEND_PAYOUT", show_segment=show_segment, show_trend=show_trend)
#      15 # plot.plot_historical_kpi(tickers=tickers, kpi="NET_MARGIN", show_segment=show_segment, show_trend=show_trend)
#
# File ~/Desenvolvimento/investment-analysis/analysis/plot.py:151, in plot_historical_kpi(tickers, kpi, show_segment, show_trend)
#     148     if show_trend:
#     149         print(df[value_column])
# --> 151         _plot_trend(
#     152             x=df["DATE"],
#     153             y=df[value_column],
#     154             label=ticker + " trend",
#     155             color=p[0].get_color(),
#     156         )
#     158 plt.title(kpi)
#     159 plt.xlabel("Date")
#
# File ~/Desenvolvimento/investment-analysis/analysis/plot.py:81, in _plot_trend(x, y, label, color)
#      78 y_train = y.values.reshape(-1, 1)
#      80 model = linear_model.LinearRegression()
# ---> 81 model.fit(x_train, y_train)
#      83 y_pred = model.predict(x_train)
#      85 print(label)
#
# File ~/Desenvolvimento/investment-analysis/.venv/lib/python3.8/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/Desenvolvimento/investment-analysis/.venv/lib/python3.8/site-packages/sklearn/linear_model/_base.py:678, in LinearRegression.fit(self, X, y, sample_weight)
#     674 n_jobs_ = self.n_jobs
#     676 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 678 X, y = self._validate_data(
#     679     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     680 )
#     682 has_sw = sample_weight is not None
#     683 if has_sw:
#
# File ~/Desenvolvimento/investment-analysis/.venv/lib/python3.8/site-packages/sklearn/base.py:622, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     620         y = check_array(y, input_name="y", **check_y_params)
#     621     else:
# --> 622         X, y = check_X_y(X, y, **check_params)
#     623     out = X, y
#     625 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/Desenvolvimento/investment-analysis/.venv/lib/python3.8/site-packages/sklearn/utils/validation.py:1162, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1142     raise ValueError(
#    1143         f"{estimator_name} requires y to be passed, but the target y is None"
#    1144     )
#    1146 X = check_array(
#    1147     X,
#    1148     accept_sparse=accept_sparse,
#    (...)
#    1159     input_name="X",
#    1160 )
# -> 1162 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1164 check_consistent_length(X, y)
#    1166 return X, y
#
# File ~/Desenvolvimento/investment-analysis/.venv/lib/python3.8/site-packages/sklearn/utils/validation.py:1172, in _check_y(y, multi_output, y_numeric, estimator)
#    1170 """Isolated part of check_X_y dedicated to y validation"""
#    1171 if multi_output:
# -> 1172     y = check_array(
#    1173         y,
#    1174         accept_sparse="csr",
#    1175         force_all_finite=True,
#    1176         ensure_2d=False,
#    1177         dtype=None,
#    1178         input_name="y",
#    1179         estimator=estimator,
#    1180     )
#    1181 else:
#    1182     estimator_name = _check_estimator_name(estimator)
#
# File ~/Desenvolvimento/investment-analysis/.venv/lib/python3.8/site-packages/sklearn/utils/validation.py:957, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     951         raise ValueError(
#     952             "Found array with dim %d. %s expected <= 2."
#     953             % (array.ndim, estimator_name)
#     954         )
#     956     if force_all_finite:
# --> 957         _assert_all_finite(
#     958             array,
#     959             input_name=input_name,
#     960             estimator_name=estimator_name,
#     961             allow_nan=force_all_finite == "allow-nan",
#     962         )
#     964 if ensure_min_samples > 0:
#     965     n_samples = _num_samples(array)
#
# File ~/Desenvolvimento/investment-analysis/.venv/lib/python3.8/site-packages/sklearn/utils/validation.py:122, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     119 if first_pass_isfinite:
#     120     return
# --> 122 _assert_all_finite_element_wise(
#     123     X,
#     124     xp=xp,
#     125     allow_nan=allow_nan,
#     126     msg_dtype=msg_dtype,
#     127     estimator_name=estimator_name,
#     128     input_name=input_name,
#     129 )
#
# File ~/Desenvolvimento/investment-analysis/.venv/lib/python3.8/site-packages/sklearn/utils/validation.py:171, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     154 if estimator_name and input_name == "X" and has_nan_error:
#     155     # Improve the error message on how to handle missing values in
#     156     # scikit-learn.
#     157     msg_err += (
#     158         f"\n{estimator_name} does not accept missing values"
#     159         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     169         "#estimators-that-handle-nan-values"
#     170     )
# --> 171 raise ValueError(msg_err)
#
# ValueError: Input y contains NaN.
