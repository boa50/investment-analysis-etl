# %%
import info
import measures
import plot

### For testing purposes
# %load_ext autoreload
# %autoreload 2

# %%
info.get_sectors()
# Out:
#                   SETOR                        SUBSETOR  \
# 0   Consumo não Cíclico                    Agropecuária
# 5            Financeiro      Intermediários Financeiros
# 11                Saúde         Comércio e Distribuição
# 16                Saúde  Medicamentos e Outros Produtos
# 18    Utilidade Pública                Energia Elétrica
# 26    Utilidade Pública               Água e Saneamento
#
#                           SEGMENTO
# 0                      Agricultura
# 5                           Bancos
# 11  Medicamentos e Outros Produtos
# 16  Medicamentos e Outros Produtos
# 18                Energia Elétrica
# 26               Água e Saneamento

# %%
info.get_companies_by_segmento("Energia Elétrica")
# Out:
#     CD_CVM                                           NOME MAIN_TICKER  \
# 18    2437                                     ELETROBRAS       ELET3
# 19    2453                                          CEMIG       CMIG4
# 20   15539                                NEOENERGIA S.A.       NEOE3
# 21   17329                              TRACTEBEL ENERGIA       EGIE3
# 22   18376                                          CTEEP       TRPL4
# 23   18660                              CPFL ENERGIA S.A.       CPFE3
# 24   20010                         EQUATORIAL ENERGIA S/A       EQTL3
# 25   20257  TRANSMISSORA ALIANÇA DE ENERGIA ELÉTRICA S.A.       TAEE4
#
#     FOUNDATION
# 18        1962
# 19        1952
# 20        1997
# 21        1998
# 22        1999
# 23        1998
# 24        1999
# 25        2006

# %%
measures.get_latest_values_by_segmento("Água e Saneamento")
# Out:
#      TICKER       PRICE      BAZIN          PL       PVP  DIVIDEND_YIELD  \
# 0     SBSP3   92.220001  50.258889    5.824615  1.662754        0.015619
# 1     AMBP3  162.000000   2.953185 -203.076701  9.587074        0.000000
# 2     CSMG3   25.160000  50.383793    6.832520  1.216177        0.144122
# 3     SAPR4    6.120000  14.093377    6.176845  0.876034        0.045442
# 4     CASN4    6.557730   1.205730   40.915819  3.447815        0.001843
# 5     ORVR3   41.360001   1.205730   19.614602  3.912742        0.000000
# 0  SEGMENTO    0.000000   0.000000  -20.618717  3.450433        0.034504
#
#    DIVIDEND_PAYOUT       ROE  CAGR_5_YEARS_PROFIT  CAGR_5_YEARS_REVENUE  \
# 0         0.090976  0.285470             0.231660              0.211263
# 1        -0.000000 -0.047209             0.231660              0.211263
# 2         0.984718  0.177998             0.156408              0.094755
# 3         0.280691  0.141825             0.081129              0.085992
# 4         0.075412  0.084266             0.115491              0.109394
# 5         0.000000  0.199481             0.115491              0.109394
# 0         0.238633  0.140305             0.146172              0.125351
#
#    NET_MARGIN  NET_DEBT_BY_EBIT  NET_DEBT_BY_EQUITY        PROFIT  \
# 0    0.228187          1.098727            0.532545  1.082188e+10
# 1   -0.021671          4.044289            1.728121 -1.332540e+08
# 2    0.177985          2.480241            0.644406  1.400240e+09
# 3    0.221200          2.025199            0.453146  1.497298e+09
# 4    0.099110          3.971980            0.881725  1.844200e+08
# 5    0.200622          3.486820            1.254645  1.749130e+08
# 0    0.150906          2.851209            0.915765  0.000000e+00
#
#    PROFIT_SEGMENTO   NET_REVENUE  NET_REVENUE_SEGMENTO          EBIT  \
# 0     7.332197e+09  4.742539e+10          3.730012e+10  1.837420e+10
# 1     3.147781e+09  6.148928e+09          1.601329e+10  1.206108e+09
# 2     1.112878e+09  7.867165e+09          5.661398e+09  2.043864e+09
# 3     1.075819e+09  6.768980e+09          5.472872e+09  2.362243e+09
# 4     8.777351e+08  1.860768e+09          4.465186e+09  4.858270e+08
# 5     3.990854e+08  8.718540e+08          2.030214e+09  3.155090e+08
# 0     0.000000e+00  0.000000e+00          0.000000e+00  0.000000e+00
#
#    EBIT_SEGMENTO
# 0   1.303279e+10
# 1   5.595099e+09
# 2   1.978111e+09
# 3   1.912240e+09
# 4   1.560151e+09
# 5   7.093637e+08
# 0   0.000000e+00

# %%
# tickers=["CMIG4"]
# tickers=["CPFE3", "EGIE3", "TRPL4", "TAEE4"]
tickers=["CMIG4", "CPFE3", "EGIE3", "TRPL4", "TAEE4"]
kpis = ["NET_DEBT_BY_EQUITY", "NET_DEBT_BY_EBIT", "PROFIT", "ROE", "CAGR_5_YEARS_PROFIT", "DIVIDEND_YIELD", "DIVIDEND_PAYOUT", "NET_MARGIN", "PL", "PVP"]
show_segment = False
show_trend = True
is_inflation_weighted = True
is_time_weighted= True
kpi=kpis[-2]

plot.plot_historical_kpi(tickers=tickers, kpi=kpi, show_segment=show_segment, show_trend=show_trend, is_inflation_weighted=is_inflation_weighted)
    
# for ticker in tickers:
#     plot.plot_equity_evolution(ticker, is_inflation_weighted=is_inflation_weighted)
    
for ticker in tickers:
    print(ticker)
    if kpi in ["NET_DEBT_BY_EBIT", "NET_DEBT_BY_EQUITY"]:
        kpi_info = measures.get_kpi_info(ticker, kpi, thresholds=[1], is_time_weighted=is_time_weighted, is_inflation_weighted=is_inflation_weighted)
    elif kpi == "DIVIDEND_PAYOUT":
        kpi_info = measures.get_kpi_info(ticker, kpi, thresholds=[0.2, 0.5], is_time_weighted=is_time_weighted, is_inflation_weighted=is_inflation_weighted)
    else:
        kpi_info = measures.get_kpi_info(ticker, kpi, is_time_weighted=is_time_weighted, is_inflation_weighted=is_inflation_weighted)
    
    print(kpi_info["volatility"], kpi_info["max_drawdown"], kpi_info["pain_index"])
# Out:
# Getting values for CMIG4
# m: 1.095805771815091e-17
# CMIG4 Last Value: 4.170654945778684
# m: -1.5895836891433964e-17
# Getting values for CPFE3
# m: 1.640233930674189e-17
# CPFE3 Last Value: 6.743325780476283
# m: -4.339443850808256e-17
# Getting values for EGIE3
# m: 1.1023864912944955e-17
# EGIE3 Last Value: 7.338279965099609
# m: 9.155585926284982e-18
# Getting values for TRPL4
# m: 1.1221618293410584e-17
# TRPL4 Last Value: 4.729782002363429
# m: -1.0429054647166555e-18
# Getting values for TAEE4
# m: 1.5004223396716105e-17
# TAEE4 Last Value: 7.074832447971901
# m: 2.0606335561039978e-17
# CMIG4
# Getting values for CMIG4
# m: 1.095805771815091e-17
# 8.395405572713381 -8.285058343454844 -0.8416073095276757
# CPFE3
# Getting values for CPFE3
# m: 1.640233930674189e-17
# 5.418152910216674 -1.0695312356855726 -0.2001975932924539
# EGIE3
# Getting values for EGIE3
# m: 1.1023864912944955e-17
# 2.603071312137651 -1.069717602366137 -0.35586863278336067
# TRPL4
# Getting values for TRPL4
# m: 1.1221618293410584e-17
# 2.0775705810502876 -1.1102969839055172 -0.6040713794570282
# TAEE4
# Getting values for TAEE4
# m: 1.5004223396716105e-17
# 2.1069498209412285 -1.1263238023574538 -0.384191558739868

# %%
kpi = "DIVIDEND_PAYOUT"
# kpi = "NET_DEBT_BY_EBIT"
# kpi = "PROFIT"
# tickers=["SBSP3"]

for ticker in tickers:
    print(ticker)
    kpi_info = measures.get_kpi_info(ticker, kpi, thresholds=[0.2, 0.5], is_time_weighted=True)
    
    print(kpi_info["volatility"], kpi_info["max_drawdown"], kpi_info["pain_index"])
    
print()

for ticker in tickers:
    print(ticker)
    kpi_info = measures.get_kpi_info(ticker, kpi, thresholds=[0.2, 0.5], is_time_weighted=False)
    
    print(kpi_info["volatility"], kpi_info["max_drawdown"], kpi_info["pain_index"])

    
# for ticker in tickers:
#     print(ticker)
#     kpi_info = measures.get_kpi_info(ticker, kpi, thresholds=[3])
    
#     print(kpi_info["volatility"], kpi_info["max_drawdown"], kpi_info["pain_index"])
    
    
# for ticker in tickers:
#     print(ticker)
#     kpi_info = measures.get_kpi_info(ticker, kpi)
    
#     print(kpi_info["volatility"], kpi_info["max_drawdown"], kpi_info["pain_index"])
# Out:
# CMIG4
# True
# 2.6051110830425324 -33.274843884318074 -1.3428683324740591
#
# CMIG4
# False
# 2.6051110830425324 -33.274843884318074 -1.927238079301401
