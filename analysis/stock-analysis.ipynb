# %%
import info
import measures
import plot

# %%
info.get_sectors()
# Out:
#                   SETOR                        SUBSETOR  \
# 0   Consumo não Cíclico                    Agropecuária
# 5            Financeiro      Intermediários Financeiros
# 11                Saúde         Comércio e Distribuição
# 16                Saúde  Medicamentos e Outros Produtos
# 18    Utilidade Pública                Energia Elétrica
# 26    Utilidade Pública               Água e Saneamento
#
#                           SEGMENTO
# 0                      Agricultura
# 5                           Bancos
# 11  Medicamentos e Outros Produtos
# 16  Medicamentos e Outros Produtos
# 18                Energia Elétrica
# 26               Água e Saneamento

# %%
info.get_companies_by_segmento("Bancos")
# Out:
#     CD_CVM                   DENOM_COMERC MAIN_TICKER  FOUNDATION
# 5      906            BANCO BRADESCO S.A.       BBDC4        1943
# 6      922         BANCO DA AMAZONIA S.A.       BAZA3        1942
# 7     1023           BANCO DO BRASIL S.A.       BBAS3        1808
# 8    19348                  ITAÚ UNIBANCO       ITUB4        1943
# 9    20532  BANCO SANTANDER (BRASIL) S.A.       SANB4        1982
# 10   22616          BANCO UBS PACTUAL S/A       BPAC3        1983

# %%
measures.get_latest_values_by_segmento("Bancos")
# Out:
#      TICKER      PRICE       BAZIN         PL       PVP  DIVIDEND_YIELD  \
# 0     ITUB4  35.009998   29.160461   9.074735  1.693078        0.067122
# 1     BPAC3  15.160000    7.775642  15.934074  3.286497        0.017279
# 2     BBDC4  15.320000   17.557902  12.216371  0.987205        0.097275
# 3     BBAS3  26.559999   47.046683   4.355350  0.829582        0.094818
# 4     SANB4  14.760000   42.524998  10.480266  0.941354        0.042861
# 5     BAZA3  90.019997  120.293233   3.827728  0.781008        0.073597
# 0  SEGMENTO   0.000000    0.000000   9.314754  1.419787        0.065492
#
#    DIVIDEND_PAYOUT       ROE  CGAR_5_YEARS_PROFIT  CGAR_5_YEARS_REVENUE  \
# 0         0.609115  0.186571             0.071490              0.205954
# 1         0.275318  0.206256             0.230281              0.328256
# 2         1.188344  0.088396            -0.062315              0.116164
# 3         0.412965  0.190474             0.150059              0.190728
# 4         0.449198  0.096482            -0.051505              0.130523
# 5         0.281708  0.204040             0.466331              0.272122
# 0         0.536108  0.162036             0.134057              0.207291
#
#    NET_MARGIN        PROFIT  PROFIT_SEGMENTO   NET_REVENUE  \
# 0    0.117601  3.782400e+10     4.026615e+10  3.216290e+11
# 1    0.250933  1.094716e+10     2.046288e+10  4.362584e+10
# 2    0.070280  1.481990e+10     1.912615e+10  2.108706e+11
# 3    0.131440  3.494804e+10     1.785602e+10  2.658851e+11
# 4    0.085809  1.142951e+10     1.298378e+10  1.331977e+11
# 5    0.297412  1.318372e+09     5.919946e+08  4.432811e+09
# 0    0.158912  0.000000e+00     0.000000e+00  0.000000e+00
#
#    NET_REVENUE_SEGMENTO          EBIT  EBIT_SEGMENTO        EQUITY  \
# 0          3.544563e+11  4.502400e+10   4.703632e+10  2.027330e+11
# 1          1.801314e+11  1.197988e+10   2.390342e+10  5.307558e+10
# 2          1.683644e+11  1.242933e+10   2.234194e+10  1.676536e+11
# 3          1.571836e+11  4.108161e+10   2.085825e+10  1.834792e+11
# 4          1.142941e+11  1.786453e+10   1.516682e+10  1.184628e+11
# 5          5.211232e+09  1.618939e+09   6.915299e+08  6.461355e+09
# 0          0.000000e+00  0.000000e+00   0.000000e+00  0.000000e+00
#
#    EQUITY_SEGMENTO    MARKET_CAP
# 0     2.648055e+11  3.432428e+11
# 1     1.345717e+11  1.744328e+11
# 2     1.257809e+11  1.630380e+11
# 3     1.174280e+11  1.522109e+11
# 4     8.538629e+10  1.106783e+11
# 5     3.893181e+09  5.046369e+09
# 0     0.000000e+00  0.000000e+00

# %%
ticker = "BBAS3"
show_segment = True

plot.plot_equity_evolution(ticker)
plot.plot_historical_kpi(ticker, kpi="PROFIT", show_segment=show_segment)
plot.plot_historical_kpi(ticker, kpi="ROE", show_segment=show_segment)
