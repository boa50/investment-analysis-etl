# %%
import info
import measures
import plot

### For testing purposes
# %load_ext autoreload
# %autoreload 2

# %%
info.get_sectors()
# Out:
#                   SETOR                        SUBSETOR  \
# 0   Consumo não Cíclico                    Agropecuária
# 5            Financeiro      Intermediários Financeiros
# 11                Saúde         Comércio e Distribuição
# 16                Saúde  Medicamentos e Outros Produtos
# 18    Utilidade Pública                Energia Elétrica
# 26    Utilidade Pública               Água e Saneamento
#
#                           SEGMENTO
# 0                      Agricultura
# 5                           Bancos
# 11  Medicamentos e Outros Produtos
# 16  Medicamentos e Outros Produtos
# 18                Energia Elétrica
# 26               Água e Saneamento

# %%
info.get_companies_by_segmento("Água e Saneamento")
# Out:
#     CD_CVM                                  DENOM_COMERC MAIN_TICKER  \
# 26   14443                                        SABESP       SBSP3
# 27   16861                                         CASAN       CASN4
# 28   18627                                       SANEPAR       SAPR4
# 29   19445                                     COPASA MG       CSMG3
# 30   24961  AMBIPAR PARTICIPAÇÕES E EMPREENDIMENTOS S.A.       AMBP3
# 31   25550           ORIZON VALORIZAÇÃO DE RESÍDUOS S.A.       ORVR3
#
#     FOUNDATION
# 26        1973
# 27        1970
# 28        1963
# 29        1963
# 30        1995
# 31        2009

# %%
measures.get_latest_values_by_segmento("Água e Saneamento")
# Out:
#      TICKER       PRICE      BAZIN          PL       PVP  DIVIDEND_YIELD  \
# 0     SBSP3   91.570000  50.258889   11.264529  1.968388        0.015730
# 1     AMBP3  124.849998   2.953185 -145.887328  8.217205        0.000000
# 2     CSMG3   23.190001  50.383793    6.002414  1.155370        0.156365
# 3     SAPR4    5.350000  14.093377    5.330868  0.794215        0.051983
# 4     CASN4    6.557730   1.205730   64.753798  3.566974        0.001843
# 5     ORVR3   47.130001   1.205730   28.422007  4.834756        0.000000
# 0  SEGMENTO    0.000000   0.000000   -5.018952  3.422818        0.037654
#
#    DIVIDEND_PAYOUT       ROE  CGAR_5_YEARS_PROFIT  CGAR_5_YEARS_REVENUE  \
# 0         0.177192  0.174742             0.118470              0.185720
# 1        -0.000000 -0.056326             0.118470              0.185720
# 2         0.938570  0.192484             0.192142              0.095856
# 3         0.277113  0.148984             0.109498              0.089537
# 4         0.119347  0.055085             0.056129              0.099865
# 5         0.000000  0.170106             0.056129              0.099865
# 0         0.252037  0.114179             0.119059              0.117744
#
#    NET_MARGIN  NET_DEBT_BY_EBIT  NET_DEBT_BY_EQUITY        PROFIT  \
# 0    0.142902          1.625806            0.522793  5.556291e+09
# 1   -0.027443          4.787212            2.091078 -1.429540e+08
# 2    0.190831          2.207992            0.582763  1.469087e+09
# 3    0.227551          2.059398            0.485895  1.516629e+09
# 4    0.065744          4.714448            0.864522  1.165290e+08
# 5    0.168696          3.581450            1.191099  1.375510e+08
# 0    0.128047          3.162718            0.956358  0.000000e+00
#
#    PROFIT_SEGMENTO   NET_REVENUE  NET_REVENUE_SEGMENTO          EBIT  \
# 0     4.844181e+09  3.888180e+10          3.417253e+10  1.022464e+10
# 1     1.614122e+09  5.209203e+09          1.138657e+10  1.108606e+09
# 2     6.824893e+08  7.698348e+09          4.814516e+09  2.014405e+09
# 3     6.257483e+08  6.665008e+09          4.414246e+09  2.401825e+09
# 4     5.840118e+08  1.772466e+09          4.119822e+09  3.879220e+08
# 5     3.025805e+08  8.153790e+08          2.134507e+09  2.689260e+08
# 0     0.000000e+00  0.000000e+00          0.000000e+00  0.000000e+00
#
#    EBIT_SEGMENTO
# 0   9.184560e+09
# 1   3.060372e+09
# 2   1.293999e+09
# 3   1.186418e+09
# 4   1.107286e+09
# 5   5.736921e+08
# 0   0.000000e+00

# %%
tickers=["CSMG3", "SAPR4", "SBSP3"]
# tickers=["SBSP3"]
show_segment = False
show_trend = True

# for ticker in tickers:
#     plot.plot_equity_evolution(ticker)
    
# plot.plot_historical_kpi(tickers=tickers, kpi="NET_DEBT_BY_EQUITY", show_segment=show_segment, show_trend=show_trend)
# plot.plot_historical_kpi(tickers=tickers, kpi="NET_DEBT_BY_EBIT", show_segment=show_segment, show_trend=show_trend)
plot.plot_historical_kpi(tickers=tickers, kpi="PROFIT", show_segment=show_segment, show_trend=show_trend)
# plot.plot_historical_kpi(tickers=tickers, kpi="ROE", show_segment=show_segment, show_trend=show_trend)
# plot.plot_historical_kpi(tickers=tickers, kpi="CGAR_5_YEARS_PROFIT", show_segment=show_segment, show_trend=show_trend)
# plot.plot_historical_kpi(tickers=tickers, kpi="DIVIDEND_YIELD", show_segment=show_segment, show_trend=show_trend)
# plot.plot_historical_kpi(tickers=tickers, kpi="DIVIDEND_PAYOUT", show_segment=show_segment, show_trend=show_trend)
# plot.plot_historical_kpi(tickers=tickers, kpi="NET_MARGIN", show_segment=show_segment, show_trend=show_trend)
# Out:
# m: 3.727373482315632e-09
# Last Value: [1.18624927e+09]
# m: 3.658589015632242e-09
# Last Value: [1.4722605e+09]
# m: 1.024924310863524e-08
# Last Value: [4.00513882e+09]

# %%
kpi = "DIVIDEND_PAYOUT"
# kpi = "NET_DEBT_BY_EBIT"
# kpi = "PROFIT"
# tickers=["SBSP3"]

for ticker in tickers:
    print(ticker)
    kpi_info = measures.get_kpi_info(ticker, kpi, thresholds=[0.2, 0.5], is_time_weighted=True)
    
    print(kpi_info["volatility"], kpi_info["max_drawdown"], kpi_info["pain_index"])
    
print()

for ticker in tickers:
    print(ticker)
    kpi_info = measures.get_kpi_info(ticker, kpi, thresholds=[0.2, 0.5], is_time_weighted=False)
    
    print(kpi_info["volatility"], kpi_info["max_drawdown"], kpi_info["pain_index"])

    
# for ticker in tickers:
#     print(ticker)
#     kpi_info = measures.get_kpi_info(ticker, kpi, thresholds=[3])
    
#     print(kpi_info["volatility"], kpi_info["max_drawdown"], kpi_info["pain_index"])
    
    
# for ticker in tickers:
#     print(ticker)
#     kpi_info = measures.get_kpi_info(ticker, kpi)
    
#     print(kpi_info["volatility"], kpi_info["max_drawdown"], kpi_info["pain_index"])
# Out:
# CSMG3
# 0.44363122219046225 -5.858223028720948 -0.4898628293245595
# SAPR4
# 0.11636155510262526 -0.4131459047200021 -0.008070184738910562
# SBSP3
# 0.37121470000359086 -3.723777867152175 -0.16360875366502206
#
# CSMG3
# 0.44363122219046225 -5.858223028720948 -0.49505687020675015
# SAPR4
# 0.11636155510262526 -0.4131459047200021 -0.019012566004767657
# SBSP3
# 0.37121470000359086 -3.723777867152175 -0.23290112298744545
