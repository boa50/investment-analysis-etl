# %%
import pandas as pd
import yfinance as yf

# %%
bbas3 = yf.Ticker("BBAS3.SA")

# %%
# get all stock info
bbas3.info
# Out:
# {'address1': 'EdifIcio Banco do Brasil',
#  'address2': 'Quadra 5, Lote B Autarquias Norte Federal District',
#  'city': 'Brasília',
#  'state': 'DF',
#  'country': 'Brazil',
#  'phone': '55 80 0729 5285',
#  'website': 'https://www.bb.com.br',
#  'industry': 'Banks - Regional',
#  'industryKey': 'banks-regional',
#  'industryDisp': 'Banks - Regional',
#  'sector': 'Financial Services',
#  'sectorKey': 'financial-services',
#  'sectorDisp': 'Financial Services',
# ...

# %%
# get historical market data
hist = bbas3.history(period="10y")

# %%
hist
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2014-10-03 00:00:00-03:00   6.753668   6.853141   6.622783   6.808640
# 2014-10-06 00:00:00-03:00   8.101789   8.138437   7.329567   7.620132
# 2014-10-07 00:00:00-03:00   7.761487   8.086082   7.698662   7.915932
# 2014-10-08 00:00:00-03:00   8.075610   8.230055   7.646307   7.965667
# 2014-10-09 00:00:00-03:00   8.101786   8.402821   8.041578   8.271936
# ...                              ...        ...        ...        ...
# 2024-09-27 00:00:00-03:00  27.480000  27.620001  27.200001  27.250000
# 2024-09-30 00:00:00-03:00  27.309999  27.480000  27.180000  27.180000
# 2024-10-01 00:00:00-03:00  27.100000  27.250000  26.879999  27.080000
# 2024-10-02 00:00:00-03:00  27.299999  27.520000  27.150000  27.150000
# 2024-10-03 00:00:00-03:00  27.110001  27.120001  26.750000  26.900000
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
bbas3.history_metadata
# Out:
# {'currency': 'BRL',
#  'symbol': 'BBAS3.SA',
#  'exchangeName': 'SAO',
#  'fullExchangeName': 'São Paulo',
#  'instrumentType': 'EQUITY',
#  'firstTradeDate': 946900800,
#  'regularMarketTime': 1727986064,
#  'hasPrePostMarketData': False,
#  'gmtoffset': -10800,
#  'timezone': 'BRT',
#  'exchangeTimezoneName': 'America/Sao_Paulo',
#  'regularMarketPrice': 26.9,
#  'fiftyTwoWeekHigh': 27.12,
#  'fiftyTwoWeekLow': 26.75,
#  'regularMarketDayHigh': 27.12,
#  'regularMarketDayLow': 26.75,
#  'regularMarketVolume': 19055500,
#  'longName': 'Banco do Brasil S.A.',
#  'shortName': 'BRASIL      ON      NM',
#  'chartPreviousClose': 13.005,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'timezone': 'BRT',
#    'start': 1727959500,
#    'end': 1727960400,
#    'gmtoffset': -10800},
#   'regular': {'timezone': 'BRT',
#    'start': 1727960400,
#    'end': 1727985600,
#    'gmtoffset': -10800},
#   'post': {'timezone': 'BRT',
#    'start': 1727985600,
#    'end': 1727989200,
# ...

# %%
bbas3.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 2014-11-17 00:00:00-02:00   0.027859           0.0
# 2014-12-12 00:00:00-02:00   0.169975           0.0
# 2015-02-20 00:00:00-02:00   0.045600           0.0
# 2015-03-24 00:00:00-03:00   0.188496           0.0
# 2015-05-22 00:00:00-03:00   0.225569           0.0
# ...                              ...           ...
# 2024-04-16 00:00:00-03:00   0.000000           2.0
# 2024-06-12 00:00:00-03:00   0.457947           0.0
# 2024-06-14 00:00:00-03:00   0.204240           0.0
# 2024-08-22 00:00:00-03:00   0.474655           0.0
# 2024-09-12 00:00:00-03:00   0.186602           0.0
#
# [78 rows x 2 columns]

# %%
bbas3.dividends
# Out:
# Date
# 2014-11-17 00:00:00-02:00    0.027859
# 2014-12-12 00:00:00-02:00    0.169975
# 2015-02-20 00:00:00-02:00    0.045600
# 2015-03-24 00:00:00-03:00    0.188496
# 2015-05-22 00:00:00-03:00    0.225569
#                                ...
# 2024-03-12 00:00:00-03:00    0.205018
# 2024-06-12 00:00:00-03:00    0.457947
# 2024-06-14 00:00:00-03:00    0.204240
# 2024-08-22 00:00:00-03:00    0.474655
# 2024-09-12 00:00:00-03:00    0.186602
# Name: Dividends, Length: 77, dtype: float64

# %%
bbas3.splits
# Out:
# Date
# 2024-04-16 00:00:00-03:00    2.0
# Name: Stock Splits, dtype: float64

# %%
sector = yf.Sector('financial-services')

# %%
sector.overview
# Out:
# {'companies_count': 1405,
#  'market_cap': 9328748658688,
#  'message_board_id': 'INDEXYH103',
#  'description': 'Companies that provide financial services include banks, savings and loans, asset management companies, credit services, investment brokerage firms, and insurance companies. Companies in this sector include Allianz, JPMorgan Chase, and Legg Mason.',
#  'industries_count': 15,
#  'market_weight': 0.1459203,
#  'employee_count': 5523304}
