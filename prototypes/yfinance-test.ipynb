# %%
import pandas as pd
import yfinance as yf

# %%
cmig = yf.Ticker('AMBP3.SA')

# %%
hist1 = cmig.history(period="10y", interval="1wk")
hist1.shape[0]
# hist2 = cmig.history(period="5d")
# pd.concat([hist1, hist2]).tail(10).drop_duplicates()
# Out:
# AMBP3.SA: Period '10y' is invalid, must be one of ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', 'ytd', 'max']
# 0

# %%
pd.concat([hist1, hist2]).reset_index().tail(10).drop_duplicates()
# Out:
#                          Date       Open       High        Low      Close  \
# 257 2024-09-23 00:00:00-03:00  11.335228  11.463365  11.098667  11.157806
# 258 2024-09-30 00:00:00-03:00  11.320000  11.650000  11.110000  11.160000
# 259 2024-10-07 00:00:00-03:00  11.220000  11.320000  10.930000  11.020000
# 260 2024-10-14 00:00:00-03:00  11.020000  11.230000  10.950000  11.040000
# 261 2024-10-21 00:00:00-03:00  11.050000  11.140000  10.990000  11.030000
# 262 2024-10-16 00:00:00-03:00  11.130000  11.230000  11.030000  11.150000
# 263 2024-10-17 00:00:00-03:00  11.080000  11.160000  11.000000  11.100000
# 264 2024-10-18 00:00:00-03:00  11.170000  11.200000  10.950000  11.040000
# 265 2024-10-21 00:00:00-03:00  11.050000  11.140000  11.000000  11.120000
# 266 2024-10-22 00:00:00-03:00  11.060000  11.080000  10.990000  11.030000
#
#        Volume  Dividends  Stock Splits
# 257  56707700   0.165202           0.0
# 258  45876300   0.000000           0.0
# ...

# %%
cmig.get_shares_full()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 cmig.get_prices()
#
# AttributeError: 'Ticker' object has no attribute 'get_prices'

# %%
cmig.quarterly_income_stmt
# Out:
#                                                            2024-03-31  \
# Tax Effect Of Unusual Items                            4652783.743955
# Tax Rate For Calcs                                           0.232279
# Normalized EBITDA                                        2209906000.0
# Total Unusual Items                                        20031000.0
# Total Unusual Items Excluding Goodwill                     20031000.0
# Net Income From Continuing Operation Net Minori...       1152891000.0
# Reconciled Depreciation                                   329000000.0
# Reconciled Cost Of Revenue                               5813524000.0
# EBITDA                                                   2229937000.0
# EBIT                                                     1900937000.0
# Net Interest Income                                      -180986000.0
# Interest Expense                                          399231000.0
# ...

# %%
cmig.quarterly_balance_sheet
# Out:
#                                                      2024-03-31  \
# Treasury Shares Number                                1100013.0
# Ordinary Shares Number                             2860681881.0
# Share Issued                                       2861781894.0
# Net Debt                                           9449000000.0
# Total Debt                                        12049000000.0
# ...                                                         ...
# Cash Cash Equivalents And Short Term Investments   5403000000.0
# Other Short Term Investments                       3226000000.0
# Cash And Cash Equivalents                          2177000000.0
# Cash Equivalents                                            NaN
# Cash Financial                                              NaN
#
#                                                      2023-12-31  \
# Treasury Shares Number                                1100013.0
# Ordinary Shares Number                             2860681881.0
# ...
