# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/cad_cia_aberta.csv", encoding = "ISO-8859-1", sep=";")

# %%
df[(df["SIT"] == "ATIVO") & (df["SETOR_ATIV"] == "Bancos")].head()
# Out:
#                CNPJ_CIA            DENOM_SOCIAL            DENOM_COMERC  \
# 213  28.195.667/0001-06    BANCO ABC BRASIL S/A    BANCO ABC BRASIL S/A
# 228  61.186.680/0001-74           BANCO BMG S/A           BANCO BMG S/A
# 234  60.746.948/0001-12     BANCO BRADESCO S.A.     BANCO BRADESCO S.A.
# 235  30.306.294/0001-45   BANCO BTG PACTUAL S/A   BANCO UBS PACTUAL S/A
# 241  04.902.979/0001-44  BANCO DA AMAZÔNIA S.A.  BANCO DA AMAZONIA S.A.
#
#          DT_REG    DT_CONST DT_CANCEL MOTIVO_CANCEL    SIT  DT_INI_SIT  \
# 213  2007-07-23  1983-12-27       NaN           NaN  ATIVO  2007-07-23
# 228  2018-12-17  1965-03-25       NaN           NaN  ATIVO  2018-12-17
# 234  1977-07-20  1943-03-02       NaN           NaN  ATIVO  1977-07-20
# 235  2011-11-10  1979-01-18       NaN           NaN  ATIVO  2011-11-10
# 241  1977-07-20  1942-07-09       NaN           NaN  ATIVO  1977-07-20
#
#      CD_CVM  ... UF_RESP PAIS_RESP    CEP_RESP DDD_TEL_RESP    TEL_RESP  \
# ...

# %%
df.columns
# Out:
# Index(['CNPJ_CIA', 'DENOM_SOCIAL', 'DENOM_COMERC', 'DT_REG', 'DT_CONST',
#        'DT_CANCEL', 'MOTIVO_CANCEL', 'SIT', 'DT_INI_SIT', 'CD_CVM',
#        'SETOR_ATIV', 'TP_MERC', 'CATEG_REG', 'DT_INI_CATEG', 'SIT_EMISSOR',
#        'DT_INI_SIT_EMISSOR', 'CONTROLE_ACIONARIO', 'TP_ENDER', 'LOGRADOURO',
#        'COMPL', 'BAIRRO', 'MUN', 'UF', 'PAIS', 'CEP', 'DDD_TEL', 'TEL',
#        'DDD_FAX', 'FAX', 'EMAIL', 'TP_RESP', 'RESP', 'DT_INI_RESP',
#        'LOGRADOURO_RESP', 'COMPL_RESP', 'BAIRRO_RESP', 'MUN_RESP', 'UF_RESP',
#        'PAIS_RESP', 'CEP_RESP', 'DDD_TEL_RESP', 'TEL_RESP', 'DDD_FAX_RESP',
#        'FAX_RESP', 'EMAIL_RESP', 'CNPJ_AUDITOR', 'AUDITOR'],
#       dtype='object')

# %%
df[df["CNPJ_CIA"] ==  "00.000.000/0001-91"]
# Out:
#                CNPJ_CIA          DENOM_SOCIAL          DENOM_COMERC  \
# 245  00.000.000/0001-91  BANCO DO BRASIL S.A.  BANCO DO BRASIL S.A.
#
#          DT_REG    DT_CONST DT_CANCEL MOTIVO_CANCEL    SIT  DT_INI_SIT  \
# 245  1977-07-20  1905-12-30       NaN           NaN  ATIVO  1977-07-20
#
#      CD_CVM  ... UF_RESP PAIS_RESP    CEP_RESP DDD_TEL_RESP    TEL_RESP  \
# 245    1023  ...      DF       NaN  70040912.0           61  34935602.0
#
#     DDD_FAX_RESP FAX_RESP       EMAIL_RESP        CNPJ_AUDITOR  \
# 245          NaN      NaN  dribb@bb.com.br  57.755.217/0001-29
#
#                                 AUDITOR
# 245  KPMG AUDITORES INDEPENDENTES LTDA.
#
# [1 rows x 47 columns]

# %%
columns = ["DENOM_SOCIAL", "SETOR_ATIV", "CD_CVM", "CNPJ_CIA", "CONTROLE_ACIONARIO", "SIT"]
df[df["CNPJ_CIA"] ==  "00.000.000/0001-91"][columns]
# Out:
#              DENOM_SOCIAL SETOR_ATIV  CD_CVM            CNPJ_CIA  \
# 245  BANCO DO BRASIL S.A.     Bancos    1023  00.000.000/0001-91
#
#     CONTROLE_ACIONARIO    SIT
# 245            ESTATAL  ATIVO
