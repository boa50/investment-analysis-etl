# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/itr_cia_aberta_DRE_con_2024.csv", encoding = "ISO-8859-1", sep=";")
df_2023 = pd.read_csv("../data/raw/itr_cia_aberta_DRE_con_2023.csv", encoding = "ISO-8859-1", sep=";")

# %%
df.head()
# Out:
#              CNPJ_CIA    DT_REFER  VERSAO        DENOM_CIA  CD_CVM  \
# 0  00.000.000/0001-91  2024-03-31       1  BCO BRASIL S.A.    1023
# 1  00.000.000/0001-91  2024-03-31       1  BCO BRASIL S.A.    1023
# 2  00.000.000/0001-91  2024-03-31       1  BCO BRASIL S.A.    1023
# 3  00.000.000/0001-91  2024-03-31       1  BCO BRASIL S.A.    1023
# 4  00.000.000/0001-91  2024-03-31       1  BCO BRASIL S.A.    1023
#
#                                     GRUPO_DFP MOEDA ESCALA_MOEDA ORDEM_EXERC  \
# 0  DF Consolidado - Demonstração do Resultado  REAL          MIL   PENÚLTIMO
# 1  DF Consolidado - Demonstração do Resultado  REAL          MIL      ÚLTIMO
# 2  DF Consolidado - Demonstração do Resultado  REAL          MIL   PENÚLTIMO
# 3  DF Consolidado - Demonstração do Resultado  REAL          MIL      ÚLTIMO
# 4  DF Consolidado - Demonstração do Resultado  REAL          MIL   PENÚLTIMO
#
#   DT_INI_EXERC DT_FIM_EXERC CD_CONTA                              DS_CONTA  \
# ...

# %%
df_concat = pd.concat([df_2023, df])
df_bbas3 = df_concat[df_concat["CD_CVM"] == 1023]
df_bbas3 = df_bbas3[df_bbas3["ORDEM_EXERC"] == "ÚLTIMO"]
df_bbas3["DS_CONTA"].unique()
# Out:
# array(['Receitas de Intermediação Financeira', 'Receita de Juros',
#        'Despesas de Intermediação Financeira', 'Despesa de Juros',
#        'Resultado Bruto de Intermediação Financeira',
#        'Outras Despesas e Receitas Operacionais',
#        'Despesa de Provisão para Perda Esperada para Risco de Crédito',
#        'Receitas de Prestação de Serviços', 'Despesas com Pessoal',
#        'Outras Despesas de Administrativas', 'Despesas Tributárias',
#        'Outras Receitas Operacionais',
#        'Ganhos/(perdas) líquidos sobre instrumentos financeiros',
#        'Resultado líquido em operações de câmbio e em conversão de transações em moedas estrangeiras',
#        'Outras', 'Outras Despesas Operacionais',
#        'Amortização de ativos intangíveis',
#        'Provisões trabalhistas, fiscais e cíveis', 'Depreciação',
#        'Resultado da Equivalência Patrimonial',
#        'Resultado antes dos Tributos sobre o Lucro',
# ...

# %%
kips = [
    "Lucro ou Prejuízo antes das Participações e Contribuições Estatutárias", 
    "Lucro ou Prejuízo Líquido Consolidado do Período",
    "Lucro por Ação (R$/Ação)"
    ]

disp_columns = ["DT_INI_EXERC", "DT_FIM_EXERC", "DS_CONTA", "VL_CONTA"]

df_bbas3[df_bbas3["DS_CONTA"].isin(kips)][disp_columns]
# Out:
#     DT_INI_EXERC DT_FIM_EXERC  \
# 55    2023-01-01   2023-03-31
# 59    2023-01-01   2023-03-31
# 65    2023-01-01   2023-03-31
# 184   2023-01-01   2023-06-30
# 185   2023-04-01   2023-06-30
# 192   2023-01-01   2023-06-30
# 193   2023-04-01   2023-06-30
# 204   2023-01-01   2023-06-30
# 205   2023-04-01   2023-06-30
# 332   2023-01-01   2023-09-30
# 333   2023-07-01   2023-09-30
# 340   2023-01-01   2023-09-30
# 341   2023-07-01   2023-09-30
# 352   2023-01-01   2023-09-30
# 353   2023-07-01   2023-09-30
# 55    2024-01-01   2024-03-31
# 59    2024-01-01   2024-03-31
# 65    2024-01-01   2024-03-31
# 184   2024-01-01   2024-06-30
# 185   2024-04-01   2024-06-30
# 192   2024-01-01   2024-06-30
# 193   2024-04-01   2024-06-30
# 204   2024-01-01   2024-06-30
# 205   2024-04-01   2024-06-30
#
#                                               DS_CONTA     VL_CONTA
# 55   Lucro ou Prejuízo antes das Participações e Co...   7290982.00
# ...
